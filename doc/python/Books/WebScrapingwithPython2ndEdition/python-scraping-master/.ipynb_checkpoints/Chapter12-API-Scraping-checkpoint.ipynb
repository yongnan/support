# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import json
import datetime
import random
import re

random.seed(datetime.datetime.now())
def getLinks(articleUrl):
    html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).findAll('a', 
        href=re.compile('^(/wiki/)((?!:).)*$'))

def getHistoryIPs(pageUrl):
    #Format of revision history pages is: 
    #http://en.wikipedia.org/w/index.php?title=Title_in_URL&action=history
    pageUrl = pageUrl.replace('/wiki/', '')
    historyUrl = 'http://en.wikipedia.org/w/index.php?title={}&action=history'.format(pageUrl)
    print('history url is: {}'.format(historyUrl))
    html = urlopen(historyUrl)
    bs = BeautifulSoup(html, 'html.parser')
    #finds only the links with class "mw-anonuserlink" which has IP addresses 
    #instead of usernames
    ipAddresses = bs.findAll('a', {'class':'mw-anonuserlink'})
    addressList = set()
    for ipAddress in ipAddresses:
        addressList.add(ipAddress.get_text())
    return addressList

links = getLinks('/wiki/Python_(programming_language)')

while(len(links) > 0):
    for link in links:
        print('-'*20) 
        historyIPs = getHistoryIPs(link.attrs['href'])
        for historyIP in historyIPs:
            print(historyIP)

    newLink = links[random.randint(0, len(links)-1)].attrs['href']
    links = getLinks(newLink)
# Out:
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Programming_paradigm&action=history
# 2405:204:6694:d402::2964:90a1
# 2601:14b:4301:19c3:9107:8bad:dbf7:5803
# 197.255.127.246
# 192.159.69.162
# 174.254.128.149
# 49.197.5.59
# 218.17.157.55
# 68.151.180.83
# 213.133.47.254
# 2a02:c7d:a492:f200:e126:2b36:53ca:513a
# 42.111.56.168
# 129.7.106.20
# 31.223.170.65
# 192.117.105.47
# 2605:6000:ec0f:c800:edfd:179f:b648:b4b9
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Multi-paradigm_programming_language&action=history
# 98.197.198.46
# 75.139.254.117
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Functional_programming&action=history
# 178.197.224.100
# 174.116.65.139
# 210.212.209.66
# 49.197.5.59
# 180.168.253.65
# 212.112.100.239
# 17.65.174.217
# 205.175.119.118
# 129.7.106.20
# 90.95.200.195
# 2405:205:24a7:f8d4:4a2c:f2a7:55e5:7d7d
# 194.55.194.254
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Imperative_programming&action=history
# 83.244.156.56
# 140.177.205.223
# 5.199.208.23
# 197.239.7.126
# 111.92.130.14
# 188.146.23.38
# 94.118.222.35
# 152.231.35.89
# 178.208.206.244
# 117.136.79.80
# 2600:1004:b151:6515:1c2a:675b:bb28:2986
# 194.181.240.192
# 107.107.62.0
# 2604:2000:b064:3300:6dd3:b07e:494d:c5cd
# 85.133.27.110
# 15.203.233.84
# 114.79.32.242
# 176.60.44.112
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Object-oriented_programming&action=history
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-39231a97fa80> in <module>
#      34     for link in links:
#      35         print('-'*20)
# ---> 36         historyIPs = getHistoryIPs(link.attrs['href'])
#      37         for historyIP in historyIPs:
#      38             print(historyIP)
#
# <ipython-input-2-39231a97fa80> in getHistoryIPs(pageUrl)
#      20     print('history url is: {}'.format(historyUrl))
#      21     html = urlopen(historyUrl)
# ---> 22     bs = BeautifulSoup(html, 'html.parser')
#      23     #finds only the links with class "mw-anonuserlink" which has IP addresses
#      24     #instead of usernames
#
# ~/Env/pwscb2nd/lib/python3.7/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     279             self.reset()
#     280             try:
# --> 281                 self._feed()
#     282                 break
#     283             except ParserRejectedMarkup:
#
# ~/Env/pwscb2nd/lib/python3.7/site-packages/bs4/__init__.py in _feed(self)
#     340         self.builder.reset()
#     341
# --> 342         self.builder.feed(self.markup)
#     343         # Close out any unfinished strings and close all the open tags.
#     344         self.endData()
#
# ~/Env/pwscb2nd/lib/python3.7/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     245         parser.soup = self.soup
#     246         try:
# --> 247             parser.feed(markup)
#     248             parser.close()
#     249         except HTMLParseError as e:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/html/parser.py in parse_starttag(self, i)
#     343             self.handle_startendtag(tag, attrs)
#     344         else:
# --> 345             self.handle_starttag(tag, attrs)
#     346             if tag in self.CDATA_CONTENT_ELEMENTS:
#     347                 self.set_cdata_mode(tag)
#
# ~/Env/pwscb2nd/lib/python3.7/site-packages/bs4/builder/_htmlparser.py in handle_starttag(self, name, attrs, handle_empty_element)
#     100             attrvalue = '""'
#     101         #print "START", name
# --> 102         tag = self.soup.handle_starttag(name, None, None, attr_dict)
#     103         if tag and tag.is_empty_element and handle_empty_element:
#     104             # Unlike other parsers, html.parser doesn't send separate end tag
#
# ~/Env/pwscb2nd/lib/python3.7/site-packages/bs4/__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs)
#     577
#     578         # print "Start tag %s: %s" % (name, attrs)
# --> 579         self.endData()
#     580
#     581         if (self.parse_only and len(self.tagStack) <= 1
#
# ~/Env/pwscb2nd/lib/python3.7/site-packages/bs4/__init__.py in endData(self, containerClass)
#     417
#     418             o = containerClass(current_data)
# --> 419             self.object_was_parsed(o)
#     420
#     421     def object_was_parsed(self, o, parent=None, most_recent_element=None):
#
# ~/Env/pwscb2nd/lib/python3.7/site-packages/bs4/__init__.py in object_was_parsed(self, o, parent, most_recent_element)
#     445
#     446             # Check that links are proper across tag parent boundaries
# --> 447             child = self._linkage_fixer(parent)
#     448
#     449     def _linkage_fixer(self, el, _recursive_call=False):
#
# ~/Env/pwscb2nd/lib/python3.7/site-packages/bs4/__init__.py in _linkage_fixer(self, el, _recursive_call)
#     497             # This index is a tag, dig deeper for a "last descendant" fixing linkage along the way
#     498             if isinstance(child, Tag) and child.contents:
# --> 499                 descendant = self._linkage_fixer(child, True)
#     500                 # A bubbled up descendant should have no next siblings
#     501                 # as it is last in its content list.
#
# ~/Env/pwscb2nd/lib/python3.7/site-packages/bs4/__init__.py in _linkage_fixer(self, el, _recursive_call)
#     497             # This index is a tag, dig deeper for a "last descendant" fixing linkage along the way
#     498             if isinstance(child, Tag) and child.contents:
# --> 499                 descendant = self._linkage_fixer(child, True)
#     500                 # A bubbled up descendant should have no next siblings
#     501                 # as it is last in its content list.
#
# ~/Env/pwscb2nd/lib/python3.7/site-packages/bs4/__init__.py in _linkage_fixer(self, el, _recursive_call)
#     497             # This index is a tag, dig deeper for a "last descendant" fixing linkage along the way
#     498             if isinstance(child, Tag) and child.contents:
# --> 499                 descendant = self._linkage_fixer(child, True)
#     500                 # A bubbled up descendant should have no next siblings
#     501                 # as it is last in its content list.
#
# ~/Env/pwscb2nd/lib/python3.7/site-packages/bs4/__init__.py in _linkage_fixer(self, el, _recursive_call)
#     497             # This index is a tag, dig deeper for a "last descendant" fixing linkage along the way
#     498             if isinstance(child, Tag) and child.contents:
# --> 499                 descendant = self._linkage_fixer(child, True)
#     500                 # A bubbled up descendant should have no next siblings
#     501                 # as it is last in its content list.
#
# ~/Env/pwscb2nd/lib/python3.7/site-packages/bs4/__init__.py in _linkage_fixer(self, el, _recursive_call)
#     471             # That child should have no previous sibling
#     472             if idx == 0:
# --> 473                 if el.parent is not None:
#     474                     if el.next_element is not child:
#     475                         el.next_element = child
#
# KeyboardInterrupt:

# %%
def getCountry(ipAddress):
    try:
        response = urlopen(
            'http://freegeoip.net/json/{}'.format(ipAddress)).read().decode('utf-8')
    except HTTPError:
        return None
    responseJson = json.loads(response)
    return responseJson.get('country_code')
    
links = getLinks('/wiki/Python_(programming_language)')

while(len(links) > 0):
    for link in links:
        print('-'*20) 
        historyIPs = getHistoryIPs(link.attrs["href"])
        for historyIP in historyIPs:
            country = getCountry(historyIP)
            if country is not None:
                print('{} is from {}'.format(historyIP, country))

    newLink = links[random.randint(0, len(links)-1)].attrs['href']
    links = getLinks(newLink)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4f510a55b514> in <module>
#       8     return responseJson.get('country_code')
#       9
# ---> 10 links = getLinks('/wiki/Python_(programming_language)')
#      11
#      12 while(len(links) > 0):
#
# NameError: name 'getLinks' is not defined
